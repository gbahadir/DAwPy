# %% [markdown]
# <p style="text-align: center"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings                         # uyari vermemesi icin
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# notebook'un gorsellestirilmesi icin
# %matplotlib inline                    

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 150
pd.options.display.max_columns = 100

# %% [markdown]
# # Read data from file

# %%
df = pd.read_csv("adult_eda.csv")

# %% [markdown]
# # Try to understand what the data looks like? What are types of the features? Are there any missing values? Do I need to eliminate some features?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32561.000     38.582     13.640    17.000     28.000
# fnlwgt         32561.000 189778.367 105549.978 12285.000 117827.000
# education-num  31759.000     10.083      2.576     1.000      9.000
# capital-gain   32561.000   1077.649   7385.292     0.000      0.000
# capital-loss   32561.000     87.304    402.960     0.000      0.000
# hours-per-week 32561.000     40.437     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 237051.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# # Look at the value counts of columns that have object datatype and replace '?' like values with 'Unknown' word.

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df.describe(include="object").T
# Out:
#                 count unique                 top   freq
# workclass       32561      9             Private  22696
# education       32561     16             HS-grad  10501
# marital-status  32561      7  Married-civ-spouse  14976
# occupation      32561     15      Prof-specialty   4140
# relationship    27493      5             Husband  13193
# race            32561      5               White  27816
# sex             32561      2                Male  21790
# native-country  32561     42       United-States  29170
# salary          32561      2               <=50K  24720

# %%
object_col = df.select_dtypes(include='object').columns
object_col
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'salary'],
#       dtype='object')

# %%
for col in object_col:
    print(col)
    print("--"*5)
    print(df[col].value_counts(dropna=False))  # dropna=False: nonvalue'lari da gormek icin
    print("--"*10)
# Out:
# workclass
# ----------
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# --------------------
# education
# ----------
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64
# --------------------
# marital-status
# ----------
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64
# --------------------
# occupation
# ----------
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64
# --------------------
# relationship
# ----------
# Husband           13193
# Not-in-family      8305
# NaN                5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64
# --------------------
# race
# ----------
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64
# --------------------
# sex
# ----------
# Male      21790
# Female    10771
# Name: sex, dtype: int64
# --------------------
# native-country
# ----------
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Trinadad&Tobago                  19
# Cambodia                         19
# Thailand                         18
# Laos                             18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Hungary                          13
# Honduras                         13
# Scotland                         12
# Holand-Netherlands                1
# Name: native-country, dtype: int64
# --------------------
# salary
# ----------
# <=50K    24720
# >50K      7841
# Name: salary, dtype: int64
# --------------------

# %%
df[df.isin(['?'])].any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education-num     False
# marital-status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country     True
# salary            False
# dtype: bool

# %%
#look at workclass column here
df.workclass.value_counts(dropna=False)
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# df.loc[df.workclass == "?", "workclass"] = "Unknown"
df.workclass.replace('?','Unknown', inplace=True)

# %%
df.occupation.value_counts(dropna=False)
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df.occupation.replace('?','Unknown', inplace=True)

# %%
df["native-country"].value_counts(dropna=False)
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Trinadad&Tobago                  19
# Cambodia                         19
# Thailand                         18
# Laos                             18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Hungary                          13
# Honduras                         13
# Scotland                         12
# Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
df["native-country"].replace('?','Unknown', inplace=True)

# %%
df[df.isin(['?'])].any()
# Out:
# age               False
# workclass         False
# fnlwgt            False
# education         False
# education-num     False
# marital-status    False
# occupation        False
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country    False
# salary            False
# dtype: bool

# %%
#replace all '?' in whole df with 'Unknown'
#df=df.replace({'?':'UNKNOWN'})  # tum DF deki '?' leri 'Unknown' ile degistirir

# %% [markdown]
# # Do education and education_num columns hold similar information? If so drop the appropriate choice between them.

# %%
df.education.value_counts(dropna=False)
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
df['education-num'].value_counts(dropna=False)
# Out:
# 9.000     10215
# 10.000     7098
# 13.000     5247
# 14.000     1687
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       631
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       330
# 2.000       161
# 1.000        50
# Name: education-num, dtype: int64

# %%
df.groupby('education')['education-num'].value_counts(dropna=False)
# Out:
# education     education-num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              161
#               NaN                  7
# 5th-6th       3.000              330
#               NaN                  3
# 7th-8th       4.000              631
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5247
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10215
#               NaN                286
# Masters       14.000            1687
#               NaN                 36
# Preschool     1.000               50
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7098
#               NaN                193
# Name: education-num, dtype: int64

# %%
#drop one of them here
df.drop('education-num',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# # Impute missing values in relationship column with 'Unmarried'. Also replace 'Not-in-family','Other-relative' values in this column with 'Unmarried'?

# %%
df.relationship.value_counts(dropna=False)
# Out:
# Husband           13193
# Not-in-family      8305
# NaN                5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df.relationship.replace(np.nan, "None", inplace=True)  # NaN lari groupby yapabilmek icin str None yaptik

# %%
df["marital-status"].value_counts(dropna=False)
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
df.groupby("relationship")["marital-status"].value_counts(dropna=False)
# Out:
# relationship    marital-status
# Husband         Married-civ-spouse       13184
#                 Married-AF-spouse            9
# None            Never-married             4485
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Not-in-family   Never-married             4706
#                 Divorced                  2404
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1601
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: marital-status, dtype: int64

# %%
df.relationship.fillna("None", inplace=True)

# %%
#df.relationship.replace([np.nan, 'Not-in-family', 'Other-relative'], 'Unmarried')
#df.relationship.replace({np.nan:'Unmarried','Not-in-family':'Unmarried','Other-relative':'Unmarried'})

# %%
df.relationship.replace([np.nan, 'Not-in-family', 'Other-relative'], 'Unmarried', inplace=True)

# %%
df.relationship.value_counts()
# Out:
# Husband      13193
# Unmarried    12732
# None          5068
# Wife          1568
# Name: relationship, dtype: int64

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %% [markdown]
# # Take a look at correlation between variables and also see if there are some outliers in any of the columns.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education      marital-status  \
# 0   39         State-gov   77516  Bachelors       Never-married
# 1   50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 2   38           Private  215646    HS-grad            Divorced
# 3   53           Private  234721       11th  Married-civ-spouse
# 4   28           Private  338409  Bachelors  Married-civ-spouse
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0       Adm-clerical    Unmarried  White    Male          2174             0
# 1    Exec-managerial      Husband  White    Male             0             0
# 2  Handlers-cleaners    Unmarried  White    Male             0             0
# 3  Handlers-cleaners      Husband  Black    Male             0             0
# 4     Prof-specialty         Wife  Black  Female             0             0
#
#    hours-per-week native-country salary
# 0              40  United-States  <=50K
# 1              13  United-States  <=50K
# 2              40  United-States  <=50K
# 3              40  United-States  <=50K
# 4              40           Cuba  <=50K

# %%
df.salary.value_counts(dropna=False)
# Out:
# <=50K    24720
# >50K      7841
# Name: salary, dtype: int64

# %%
df.salary.map({"<=50K" : 0, ">50K" : 1})
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: salary, Length: 32561, dtype: int64

# %%
df["salary_num"] = df.salary.map({"<=50K" : 0, ">50K" : 1})

# %%
df.salary_num.value_counts(dropna=False)
# Out:
# 0    24720
# 1     7841
# Name: salary_num, dtype: int64

# %%
df.corr()
# Out:
#                   age  fnlwgt  capital-gain  capital-loss  hours-per-week  \
# age             1.000  -0.077         0.078         0.058           0.069
# fnlwgt         -0.077   1.000         0.000        -0.010          -0.019
# capital-gain    0.078   0.000         1.000        -0.032           0.078
# capital-loss    0.058  -0.010        -0.032         1.000           0.054
# hours-per-week  0.069  -0.019         0.078         0.054           1.000
# salary_num      0.234  -0.009         0.223         0.151           0.230
#
#                 salary_num
# age                  0.234
# fnlwgt              -0.009
# capital-gain         0.223
# capital-loss         0.151
# hours-per-week       0.230
# salary_num           1.000

# %%
df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32561.000     38.582     13.640    17.000     28.000
# fnlwgt         32561.000 189778.367 105549.978 12285.000 117827.000
# capital-gain   32561.000   1077.649   7385.292     0.000      0.000
# capital-loss   32561.000     87.304    402.960     0.000      0.000
# hours-per-week 32561.000     40.437     12.347     1.000     40.000
# salary_num     32561.000      0.241      0.428     0.000      0.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 237051.000 1484705.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000
# salary_num          0.000      0.000       1.000

# %% [markdown]
# ### age

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sns.boxplot(data=df.age)
plt.subplot(1,2,2)
sns.histplot(data=df.age);

# %%
low = df.age.quantile(0.25)
high = df.age.quantile(0.75)
IQR = high - low
low, high, IQR
# Out:
# (28.0, 48.0, 20.0)

# %%
lower_lim = low - (1.5 * IQR)
upper_lim = high + (1.5 * IQR)
lower_lim, upper_lim
# Out:
# (-2.0, 78.0)

# %%
df[df["age"] > 78]["age"].value_counts()
# Out:
# 90    43
# 79    22
# 80    22
# 81    20
# 82    12
# 84    10
# 83     6
# 85     3
# 88     3
# 86     1
# 87     1
# Name: age, dtype: int64

# %%
df[df["age"] > 78].sort_values(by="age", ascending=False)
# Out:
#        age         workclass  fnlwgt     education         marital-status  \
# 12451   90           Unknown  225063  Some-college          Never-married
# 10545   90           Private  175491       HS-grad     Married-civ-spouse
# 5406    90           Private   51744       Masters          Never-married
# 19747   90           Private  226968       7th-8th     Married-civ-spouse
# 28463   90       Federal-gov  195433       HS-grad     Married-civ-spouse
# 11512   90           Private   87285       HS-grad          Never-married
# 6232    90  Self-emp-not-inc  155981     Bachelors     Married-civ-spouse
# 24238   90           Unknown  166343       1st-4th                Widowed
# 6624    90           Private  313986          11th     Married-civ-spouse
# 14159   90         Local-gov  187749    Assoc-acdm     Married-civ-spouse
# 10210   90  Self-emp-not-inc  282095  Some-college     Married-civ-spouse
# 18277   90           Private  311184     Bachelors     Married-civ-spouse
# 20610   90           Private  206667       Masters     Married-civ-spouse
# 25303   90           Unknown  175444       7th-8th              Separated
# 15356   90           Private   90523       HS-grad                Widowed
# 222     90           Private   51744       HS-grad          Never-married
# 15892   90           Private   88991     Bachelors     Married-civ-spouse
# 12975   90           Private  250832          10th     Married-civ-spouse
# 8806    90           Private   87372   Prof-school     Married-civ-spouse
# 8963    90           Unknown   77053       HS-grad                Widowed
# 5370    90         Local-gov  227796       Masters     Married-civ-spouse
# 5272    90           Private  141758           9th          Never-married
# 19212   90           Private  139660  Some-college               Divorced
# 32277   90           Private  313749       HS-grad                Widowed
# 22220   90           Private   52386     Bachelors          Never-married
# 11996   90           Private   40388     Bachelors          Never-married
# 1040    90           Private  137018       HS-grad          Never-married
# 11731   90           Unknown   39824       HS-grad                Widowed
# 1935    90           Private  221832     Bachelors     Married-civ-spouse
# 2303    90           Private   52386  Some-college          Never-married
# 32367   90         Local-gov  214594       7th-8th     Married-civ-spouse
# 2891    90           Private  171956  Some-college              Separated
# 19489   90           Private   84553       HS-grad     Married-civ-spouse
# 5104    90           Private   52386  Some-college          Never-married
# 18832   90           Private  115306       Masters          Never-married
# 31696   90           Unknown  313986       HS-grad     Married-civ-spouse
# 24043   90  Self-emp-not-inc   82628       HS-grad          Never-married
# 18725   90         Local-gov  153602       HS-grad     Married-civ-spouse
# 4070    90           Private  313986          11th          Never-married
# 4109    90           Unknown  256514     Bachelors                Widowed
# 31030   90           Private   47929       HS-grad     Married-civ-spouse
# 18413   90           Private  313749     Bachelors          Never-married
# 8973    90           Private   46786     Bachelors     Married-civ-spouse
# 22895   88           Private   68539  Some-college               Divorced
# 21835   88  Self-emp-not-inc  187097   Prof-school     Married-civ-spouse
# 1168    88  Self-emp-not-inc  206291   Prof-school     Married-civ-spouse
# 31432   87           Unknown   90338       HS-grad                Widowed
# 24027   86           Private  149912       Masters          Never-married
# 8381    85           Private  115364       HS-grad                Widowed
# 20463   85  Self-emp-not-inc  166027       HS-grad                Widowed
# 32459   85           Private   98611     Bachelors     Married-civ-spouse
# 13025   84           Unknown  368925       5th-6th                Widowed
# 14711   84         Local-gov  135839     Assoc-voc                Widowed
# 22898   84           Unknown  127184       5th-6th     Married-civ-spouse
# 9471    84         Local-gov  163685       HS-grad                Widowed
# 11238   84      Self-emp-inc  172907  Some-college     Married-civ-spouse
# 15662   84           Private  132806       HS-grad                Widowed
# 7720    84           Private  241065       Masters          Never-married
# 27795   84           Private  388384       7th-8th     Married-civ-spouse
# 6214    84  Self-emp-not-inc  155057     Bachelors     Married-civ-spouse
# 26731   84           Private  188328       HS-grad                Widowed
# 19172   83      Self-emp-inc  272248       HS-grad               Divorced
# 16302   83  Self-emp-not-inc  213866       HS-grad                Widowed
# 23459   83      Self-emp-inc  240150          10th     Married-civ-spouse
# 24395   83      Self-emp-inc  153183     Bachelors     Married-civ-spouse
# 3963    83           Unknown  251951       HS-grad                Widowed
# 7481    83           Private  195507       HS-grad                Widowed
# 22481   82      Self-emp-inc  120408  Some-college                Widowed
# 13696   82  Self-emp-not-inc  240491       HS-grad     Married-civ-spouse
# 32494   82           Unknown  403910       HS-grad          Never-married
# 3211    82           Unknown   29441       7th-8th                Widowed
# 31855   82  Self-emp-not-inc   71438       HS-grad     Married-civ-spouse
# 20421   82           Private  147729       5th-6th                Widowed
# 19180   82           Unknown   42435          10th                Widowed
# 21812   82           Unknown  194590     Assoc-voc                Widowed
# 8431    82           Private  152148       7th-8th     Married-civ-spouse
# 24280   82      Self-emp-inc  130329       7th-8th     Married-civ-spouse
# 12492   82           Unknown   52921  Some-college                Widowed
# 14756   82           Private  132870       HS-grad                Widowed
# 20826   81           Unknown  147097     Bachelors                Widowed
# 21501   81           Private  177408       HS-grad     Married-civ-spouse
# 28948   81           Private  129338       7th-8th     Married-civ-spouse
# 29594   81  Self-emp-not-inc  193237       1st-4th                Widowed
# 29724   81           Unknown   89391   Prof-school     Married-civ-spouse
# 19495   81      Self-emp-inc  247232          10th     Married-civ-spouse
# 24560   81           Private   98116     Bachelors                Widowed
# 26012   81           Unknown  106765  Some-college                Widowed
# 32525   81           Unknown  120478     Assoc-voc               Divorced
# 19045   81         State-gov  132204       1st-4th                Widowed
# 2906    81           Private  114670           9th                Widowed
# 13928   81  Self-emp-not-inc  123959     Bachelors                Widowed
# 16762   81           Unknown   89015       HS-grad     Married-civ-spouse
# 13295   81           Private  100675       1st-4th     Married-civ-spouse
# 12830   81           Private  201398       Masters                Widowed
# 4834    81           Private  364099  Some-college               Divorced
# 3537    81  Self-emp-not-inc  137018       HS-grad                Widowed
# 918     81  Self-emp-not-inc  136063       HS-grad     Married-civ-spouse
# 7872    81           Unknown  162882       HS-grad               Divorced
# 6748    81           Private  122651  Some-college     Married-civ-spouse
# 8694    80           Unknown   29020   Prof-school     Married-civ-spouse
# 14104   80           Private  148623   Prof-school     Married-civ-spouse
# 18560   80           Unknown  172826       HS-grad     Married-civ-spouse
# 5291    80           Private  157778       Masters                Widowed
# 28721   80  Self-emp-not-inc  225892       HS-grad     Married-civ-spouse
# 3777    80           Private   87518  Some-college          Never-married
# 25397   80           Unknown   91901       HS-grad     Married-civ-spouse
# 10124   80  Self-emp-not-inc   34340       7th-8th                Widowed
# 14604   80           Private  173488  Some-college                Widowed
# 18037   80  Self-emp-not-inc  132728       HS-grad          Never-married
# 20482   80           Private  202483       HS-grad  Married-spouse-absent
# 19515   80         Local-gov   20101       HS-grad                Widowed
# 19689   80  Self-emp-not-inc  562336       HS-grad     Married-civ-spouse
# 18272   80           Private   86111     Doctorate     Married-civ-spouse
# 430     80           Unknown  107762       HS-grad                Widowed
# 20249   80           Private  252466     Assoc-voc     Married-civ-spouse
# 31814   80  Self-emp-not-inc   26865       7th-8th          Never-married
# 6439    80           Private  249983       7th-8th                Widowed
# 2754    80  Self-emp-not-inc  184335       7th-8th     Married-civ-spouse
# 16901   80  Self-emp-not-inc  101771          11th     Married-civ-spouse
# 20953   80           Unknown  174995       HS-grad     Married-civ-spouse
# 31836   80           Unknown  281768    Assoc-acdm     Married-civ-spouse
# 6000    79         Local-gov   84616          11th     Married-civ-spouse
# 3338    79           Unknown  144533       HS-grad                Widowed
# 4720    79  Self-emp-not-inc  158319       HS-grad                Widowed
# 6173    79           Private  120707     Doctorate     Married-civ-spouse
# 28176   79       Federal-gov   62176     Doctorate                Widowed
# 11099   79           Unknown  165209       HS-grad     Married-civ-spouse
# 26242   79      Self-emp-inc  183686     Bachelors     Married-civ-spouse
# 8176    79           Private  121318  Some-college     Married-civ-spouse
# 25163   79           Unknown   76641       Masters     Married-civ-spouse
# 8522    79           Private  333230       HS-grad  Married-spouse-absent
# 11532   79           Unknown  142370   Prof-school     Married-civ-spouse
# 23900   79  Self-emp-not-inc  103684       HS-grad     Married-civ-spouse
# 13026   79           Unknown  100881    Assoc-acdm     Married-civ-spouse
# 14903   79      Self-emp-inc  309272       HS-grad     Married-civ-spouse
# 16523   79           Unknown  163140       HS-grad     Married-civ-spouse
# 21343   79           Private  266119     Bachelors     Married-civ-spouse
# 20880   79           Unknown  142171       7th-8th     Married-civ-spouse
# 17609   79      Self-emp-inc   97082          12th                Widowed
# 20483   79         Local-gov  146244     Doctorate                Widowed
# 18141   79  Self-emp-not-inc   84979     Assoc-voc     Married-civ-spouse
# 19828   79           Private  172220       7th-8th                Widowed
# 74      79           Private  124744  Some-college     Married-civ-spouse
#
#               occupation relationship                race     sex  \
# 12451            Unknown         None  Asian-Pac-Islander    Male
# 10545       Craft-repair      Husband               White    Male
# 5406     Exec-managerial    Unmarried               Black    Male
# 19747  Machine-op-inspct      Husband               White    Male
# 28463       Craft-repair      Husband               White    Male
# 11512      Other-service         None               White  Female
# 6232      Prof-specialty      Husband               White    Male
# 24238            Unknown    Unmarried               Black  Female
# 6624        Craft-repair      Husband               White    Male
# 14159       Adm-clerical      Husband  Asian-Pac-Islander    Male
# 10210    Farming-fishing      Husband               White    Male
# 18277              Sales      Husband               White    Male
# 20610     Prof-specialty         Wife               White  Female
# 25303            Unknown    Unmarried               White  Female
# 15356   Transport-moving    Unmarried               White    Male
# 222        Other-service    Unmarried               Black    Male
# 15892    Exec-managerial         Wife               White  Female
# 12975    Exec-managerial      Husband               White    Male
# 8806      Prof-specialty      Husband               White    Male
# 8963             Unknown    Unmarried               White  Female
# 5370     Exec-managerial      Husband               White    Male
# 5272        Adm-clerical    Unmarried               White  Female
# 19212              Sales    Unmarried               Black  Female
# 32277       Adm-clerical    Unmarried               White  Female
# 22220     Prof-specialty    Unmarried  Asian-Pac-Islander    Male
# 11996    Exec-managerial    Unmarried               White    Male
# 1040       Other-service    Unmarried               White  Female
# 11731            Unknown    Unmarried               White    Male
# 1935     Exec-managerial      Husband               White    Male
# 2303       Other-service    Unmarried  Asian-Pac-Islander    Male
# 32367    Protective-serv      Husband               White    Male
# 2891        Adm-clerical         None               White  Female
# 19489  Machine-op-inspct      Husband               White    Male
# 5104       Other-service    Unmarried  Asian-Pac-Islander    Male
# 18832    Exec-managerial         None               White  Female
# 31696            Unknown      Husband               White    Male
# 24043    Exec-managerial    Unmarried               White    Male
# 18725      Other-service      Husband               White    Male
# 4070   Handlers-cleaners         None               White    Male
# 4109             Unknown    Unmarried               White  Female
# 31030  Machine-op-inspct      Husband               White    Male
# 18413     Prof-specialty         None               White  Female
# 8973               Sales      Husband               White    Male
# 22895       Adm-clerical    Unmarried               White  Female
# 21835    Exec-managerial      Husband               White    Male
# 1168      Prof-specialty      Husband               White    Male
# 31432            Unknown    Unmarried               White    Male
# 24027       Adm-clerical    Unmarried               White  Female
# 8381               Sales    Unmarried               White    Male
# 20463              Sales    Unmarried               White  Female
# 32459    Exec-managerial      Husband               White    Male
# 13025            Unknown    Unmarried               White    Male
# 14711       Adm-clerical    Unmarried               White  Female
# 22898            Unknown      Husband               White    Male
# 9471     Exec-managerial    Unmarried               White  Female
# 11238              Sales      Husband               White    Male
# 15662      Other-service    Unmarried               White  Female
# 7720      Prof-specialty    Unmarried               White    Male
# 27795     Prof-specialty      Husband               Black    Male
# 6214     Farming-fishing      Husband               White    Male
# 26731     Prof-specialty    Unmarried               White  Female
# 19172              Sales    Unmarried               White    Male
# 16302    Exec-managerial    Unmarried               White    Male
# 23459    Farming-fishing      Husband               White    Male
# 24395    Exec-managerial      Husband               White    Male
# 3963             Unknown    Unmarried               White  Female
# 7481     Protective-serv    Unmarried               White    Male
# 22481              Sales    Unmarried               White    Male
# 13696       Craft-repair      Husband               White    Male
# 32494            Unknown    Unmarried               White    Male
# 3211             Unknown    Unmarried               White    Male
# 31855    Farming-fishing      Husband               White    Male
# 20421      Other-service    Unmarried               White    Male
# 19180            Unknown    Unmarried               White    Male
# 21812            Unknown    Unmarried               White  Female
# 8431   Handlers-cleaners      Husband               White    Male
# 24280    Farming-fishing      Husband               White    Male
# 12492            Unknown    Unmarried  Amer-Indian-Eskimo    Male
# 14756    Exec-managerial    Unmarried               White  Female
# 20826            Unknown    Unmarried               White    Male
# 21501    Exec-managerial      Husband               White    Male
# 28948   Transport-moving      Husband               White    Male
# 29594              Sales    Unmarried               White    Male
# 29724            Unknown      Husband               White    Male
# 19495    Exec-managerial         Wife               White  Female
# 24560              Sales    Unmarried               White    Male
# 26012            Unknown    Unmarried               White  Female
# 32525            Unknown    Unmarried               White  Female
# 19045      Other-service    Unmarried               White  Female
# 2906     Priv-house-serv    Unmarried               Black  Female
# 13928     Prof-specialty    Unmarried               White  Female
# 16762            Unknown      Husband               White    Male
# 13295     Prof-specialty      Husband               White    Male
# 12830     Prof-specialty    Unmarried               White    Male
# 4834        Adm-clerical    Unmarried               White  Female
# 3537        Adm-clerical    Unmarried               White  Female
# 918      Exec-managerial      Husband               White    Male
# 7872             Unknown    Unmarried               White  Female
# 6748               Sales      Husband               White    Male
# 8694             Unknown      Husband               White    Male
# 14104     Prof-specialty      Husband               White    Male
# 18560            Unknown      Husband               White    Male
# 5291      Prof-specialty    Unmarried               White  Female
# 28721      Other-service      Husband               White    Male
# 3777      Prof-specialty    Unmarried               White    Male
# 25397            Unknown      Husband               White    Male
# 10124    Farming-fishing    Unmarried               White    Male
# 14604       Adm-clerical    Unmarried               White  Female
# 18037    Exec-managerial    Unmarried               White    Male
# 20482       Adm-clerical    Unmarried               White  Female
# 19515      Other-service    Unmarried  Amer-Indian-Eskimo  Female
# 19689    Farming-fishing      Husband               White    Male
# 18272     Prof-specialty      Husband               White    Male
# 430              Unknown    Unmarried               White    Male
# 20249       Craft-repair      Husband               White    Male
# 31814    Farming-fishing    Unmarried               White    Male
# 6439       Other-service    Unmarried               White  Female
# 2754     Farming-fishing      Husband               White    Male
# 16901    Exec-managerial      Husband               White    Male
# 20953            Unknown      Husband               White    Male
# 31836            Unknown      Husband               White    Male
# 6000     Exec-managerial      Husband               White    Male
# 3338             Unknown    Unmarried               Black  Female
# 4720       Other-service    Unmarried               White  Female
# 6173      Prof-specialty      Husband               White    Male
# 28176    Exec-managerial    Unmarried               White    Male
# 11099            Unknown      Husband               White    Male
# 26242              Sales      Husband               White    Male
# 8176        Adm-clerical      Husband               White    Male
# 25163            Unknown      Husband               White    Male
# 8522      Prof-specialty    Unmarried               White    Male
# 11532            Unknown      Husband               White    Male
# 23900    Farming-fishing      Husband               White    Male
# 13026            Unknown         Wife               White  Female
# 14903    Exec-managerial      Husband               White    Male
# 16523            Unknown      Husband               White    Male
# 21343              Sales      Husband               White    Male
# 20880            Unknown      Husband               White    Male
# 17609              Sales    Unmarried               White    Male
# 20483     Prof-specialty    Unmarried               White  Female
# 18141              Sales      Husband               White    Male
# 19828    Priv-house-serv    Unmarried               White  Female
# 74        Prof-specialty    Unmarried               White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country salary  \
# 12451             0             0              10          South  <=50K
# 10545          9386             0              50        Ecuador   >50K
# 5406              0             0              50  United-States   >50K
# 19747             0             0              40  United-States  <=50K
# 28463             0             0              30  United-States  <=50K
# 11512             0             0              24  United-States  <=50K
# 6232          10566             0              50  United-States  <=50K
# 24238             0             0              40  United-States  <=50K
# 6624              0             0              40  United-States  <=50K
# 14159             0             0              20    Philippines  <=50K
# 10210             0             0              40  United-States  <=50K
# 18277             0             0              20        Unknown  <=50K
# 20610             0             0              40  United-States   >50K
# 25303             0             0              15  United-States  <=50K
# 15356             0             0              99  United-States  <=50K
# 222               0          2206              40  United-States  <=50K
# 15892             0             0              40        England   >50K
# 12975             0             0              40  United-States  <=50K
# 8806          20051             0              72  United-States   >50K
# 8963              0          4356              40  United-States  <=50K
# 5370          20051             0              60  United-States   >50K
# 5272              0             0              40  United-States  <=50K
# 19212             0             0              37  United-States  <=50K
# 32277             0             0              25  United-States  <=50K
# 22220             0             0              40  United-States  <=50K
# 11996             0             0              55  United-States  <=50K
# 1040              0             0              40  United-States  <=50K
# 11731           401             0               4  United-States  <=50K
# 1935              0             0              45  United-States  <=50K
# 2303              0             0              35  United-States  <=50K
# 32367          2653             0              40  United-States  <=50K
# 2891              0             0              40    Puerto-Rico  <=50K
# 19489             0             0              40  United-States  <=50K
# 5104              0             0              35  United-States  <=50K
# 18832             0             0              40  United-States  <=50K
# 31696             0             0              40  United-States   >50K
# 24043          2964             0              12  United-States  <=50K
# 18725          6767             0              40  United-States  <=50K
# 4070              0             0              40  United-States  <=50K
# 4109            991             0              10  United-States  <=50K
# 31030             0             0              40  United-States  <=50K
# 18413             0             0              10  United-States  <=50K
# 8973           9386             0              15  United-States   >50K
# 22895             0             0              40  United-States  <=50K
# 21835             0             0              40  United-States  <=50K
# 1168              0             0              40  United-States  <=50K
# 31432             0             0               2  United-States  <=50K
# 24027             0             0              40  United-States  <=50K
# 8381              0             0              35  United-States  <=50K
# 20463             0             0              50  United-States  <=50K
# 32459             0             0               3         Poland  <=50K
# 13025             0             0              15  United-States  <=50K
# 14711             0             0              14  United-States  <=50K
# 22898             0             0              20  United-States  <=50K
# 9471              0             0              33  United-States  <=50K
# 11238             0             0              35  United-States   >50K
# 15662             0             0              13  United-States  <=50K
# 7720              0             0              66  United-States  <=50K
# 27795             0             0              10  United-States  <=50K
# 6214              0             0              20  United-States  <=50K
# 26731             0             0              16  United-States  <=50K
# 19172             0             0              20  United-States  <=50K
# 16302             0             0               8  United-States  <=50K
# 23459         20051             0              50  United-States   >50K
# 24395             0          2392              55  United-States   >50K
# 3963              0             0              20  United-States  <=50K
# 7481              0             0              55  United-States  <=50K
# 22481             0             0              20  United-States  <=50K
# 13696             0             0              40           Cuba  <=50K
# 32494             0             0               3  United-States  <=50K
# 3211              0             0               5  United-States  <=50K
# 31855             0             0              20  United-States  <=50K
# 20421             0             0              20  United-States  <=50K
# 19180             0             0              20  United-States  <=50K
# 21812             0             0               8  United-States  <=50K
# 8431              0             0               2  United-States  <=50K
# 24280             0             0              50  United-States  <=50K
# 12492             0             0               3  United-States  <=50K
# 14756             0          4356              18  United-States  <=50K
# 20826             0             0               5  United-States  <=50K
# 21501             0          2377              26  United-States   >50K
# 28948             0             0              10  United-States  <=50K
# 29594             0             0              45         Mexico  <=50K
# 29724             0             0              24  United-States   >50K
# 19495          2936             0              28  United-States  <=50K
# 24560             0             0              50  United-States   >50K
# 26012             0             0               4  United-States  <=50K
# 32525             0             0               1        Unknown  <=50K
# 19045             0             0              20  United-States  <=50K
# 2906           2062             0               5  United-States  <=50K
# 13928             0          1668               3        Hungary  <=50K
# 16762             0             0              18  United-States  <=50K
# 13295             0             0              15         Poland  <=50K
# 12830             0             0              60        Unknown  <=50K
# 4834              0             0              20  United-States  <=50K
# 3537              0             0              20  United-States  <=50K
# 918               0             0              30  United-States  <=50K
# 7872              0             0              35  United-States  <=50K
# 6748              0             0              15  United-States  <=50K
# 8694          10605             0              10  United-States   >50K
# 14104             0             0              35  United-States   >50K
# 18560             0             0               8  United-States  <=50K
# 5291              0             0              10  United-States  <=50K
# 28721          1409             0              40  United-States  <=50K
# 3777              0          1816              60  United-States  <=50K
# 25397             0             0              25  United-States  <=50K
# 10124             0             0              35  United-States  <=50K
# 14604             0             0              20  United-States  <=50K
# 18037             0             0              20  United-States  <=50K
# 20482             0             0              16  United-States  <=50K
# 19515             0             0              32  United-States  <=50K
# 19689             0             0              20  United-States  <=50K
# 18272             0             0              30  United-States  <=50K
# 430               0             0              24  United-States  <=50K
# 20249             0             0              24  United-States  <=50K
# 31814             0             0              20  United-States  <=50K
# 6439              0             0              24  United-States  <=50K
# 2754              0             0              30  United-States  <=50K
# 16901             0             0              25  United-States  <=50K
# 20953             0             0               8         Canada  <=50K
# 31836             0             0               4  United-States  <=50K
# 6000              0             0               7  United-States  <=50K
# 3338              0             0              30  United-States  <=50K
# 4720              0             0              24  United-States  <=50K
# 6173          20051             0              35    El-Salvador   >50K
# 28176             0             0               6  United-States   >50K
# 11099             0             0              40  United-States  <=50K
# 26242             0             0              20  United-States   >50K
# 8176              0             0              20  United-States  <=50K
# 25163         20051             0              40         Poland   >50K
# 8522              0             0               6  United-States  <=50K
# 11532             0             0              10  United-States  <=50K
# 23900             0             0              40  United-States  <=50K
# 13026             0             0               2  United-States   >50K
# 14903             0             0              40  United-States   >50K
# 16523             0             0              40  United-States   >50K
# 21343             0             0              40  United-States  <=50K
# 20880          1409             0              35  United-States  <=50K
# 17609         18481             0              45  United-States   >50K
# 20483             0             0              40  United-States  <=50K
# 18141             0             0              20  United-States   >50K
# 19828          2964             0              30  United-States  <=50K
# 74                0             0              20  United-States  <=50K
#
#        salary_num
# 12451           0
# 10545           1
# 5406            1
# 19747           0
# 28463           0
# 11512           0
# 6232            0
# 24238           0
# 6624            0
# 14159           0
# 10210           0
# 18277           0
# 20610           1
# 25303           0
# 15356           0
# 222             0
# 15892           1
# 12975           0
# 8806            1
# 8963            0
# 5370            1
# 5272            0
# 19212           0
# 32277           0
# 22220           0
# 11996           0
# 1040            0
# 11731           0
# 1935            0
# 2303            0
# 32367           0
# 2891            0
# 19489           0
# 5104            0
# 18832           0
# 31696           1
# 24043           0
# 18725           0
# 4070            0
# 4109            0
# 31030           0
# 18413           0
# 8973            1
# 22895           0
# 21835           0
# 1168            0
# 31432           0
# 24027           0
# 8381            0
# 20463           0
# 32459           0
# 13025           0
# 14711           0
# 22898           0
# 9471            0
# 11238           1
# 15662           0
# 7720            0
# 27795           0
# 6214            0
# 26731           0
# 19172           0
# 16302           0
# 23459           1
# 24395           1
# 3963            0
# 7481            0
# 22481           0
# 13696           0
# 32494           0
# 3211            0
# 31855           0
# 20421           0
# 19180           0
# 21812           0
# 8431            0
# 24280           0
# 12492           0
# 14756           0
# 20826           0
# 21501           1
# 28948           0
# 29594           0
# 29724           1
# 19495           0
# 24560           1
# 26012           0
# 32525           0
# 19045           0
# 2906            0
# 13928           0
# 16762           0
# 13295           0
# 12830           0
# 4834            0
# 3537            0
# 918             0
# 7872            0
# 6748            0
# 8694            1
# 14104           1
# 18560           0
# 5291            0
# 28721           0
# 3777            0
# 25397           0
# 10124           0
# 14604           0
# 18037           0
# 20482           0
# 19515           0
# 19689           0
# 18272           0
# 430             0
# 20249           0
# 31814           0
# 6439            0
# 2754            0
# 16901           0
# 20953           0
# 31836           0
# 6000            0
# 3338            0
# 4720            0
# 6173            1
# 28176           1
# 11099           0
# 26242           1
# 8176            0
# 25163           1
# 8522            0
# 11532           0
# 23900           0
# 13026           1
# 14903           1
# 16523           1
# 21343           0
# 20880           0
# 17609           1
# 20483           0
# 18141           1
# 19828           0
# 74              0

# %% [markdown]
# ### hours_per_week

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sns.boxplot(data=df["hours-per-week"])
plt.subplot(1,2,2)
sns.histplot(data=df["hours-per-week"], bins=10);

# %%
low = df["hours-per-week"].quantile(0.25)
high = df["hours-per-week"].quantile(0.75)
IQR = high - low
low, high, IQR
# Out:
# (40.0, 45.0, 5.0)

# %%
lower_lim = low - (1.5 * IQR)
upper_lim = high + (1.5 * IQR)
lower_lim, upper_lim
# Out:
# (32.5, 52.5)

# %%
df[df["hours-per-week"] > 52.5]["hours-per-week"].value_counts().sort_index(ascending=False)
# Out:
# 99      85
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      29
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      45
# 82       1
# 81       3
# 80     133
# 78       8
# 77       6
# 76       3
# 75      66
# 74       1
# 73       2
# 72      71
# 70     291
# 68      12
# 67       4
# 66      17
# 65     244
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1475
# 59       5
# 58      28
# 57      17
# 56      97
# 55     694
# 54      41
# 53      25
# Name: hours-per-week, dtype: int64

# %%
df[df["hours-per-week"] > 52.5].sort_values(by="hours-per-week", ascending=False)
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 25986   44         Local-gov  212665  Some-college  Married-civ-spouse
# 23179   31           Private  511289       HS-grad       Never-married
# 13558   38           Private  191103   Prof-school  Married-civ-spouse
# 9831    67           Private   35015       Masters       Never-married
# 13580   38  Self-emp-not-inc  112158       HS-grad  Married-civ-spouse
# ...    ...               ...     ...           ...                 ...
# 23481   23           Private  181820       HS-grad           Separated
# 28858   62           Private  123411       7th-8th  Married-civ-spouse
# 15889   43       Federal-gov  155106     Bachelors  Married-civ-spouse
# 15908   22         Local-gov  163205       HS-grad       Never-married
# 5345    30           Private  140011     Assoc-voc  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 25986    Protective-serv      Husband  Black    Male             0
# 23179    Farming-fishing    Unmarried  White    Male          2907
# 13558     Prof-specialty      Husband  White    Male             0
# 9831      Prof-specialty    Unmarried  White    Male             0
# 13580    Exec-managerial      Husband  White    Male             0
# ...                  ...          ...    ...     ...           ...
# 23481       Craft-repair         None  White    Male             0
# 28858   Transport-moving      Husband  White    Male             0
# 15889  Handlers-cleaners      Husband  White    Male             0
# 15908      Other-service         None  White  Female             0
# 5345   Handlers-cleaners      Husband  White    Male             0
#
#        capital-loss  hours-per-week native-country salary  salary_num
# 25986             0              99  United-States  <=50K           0
# 23179             0              99  United-States  <=50K           0
# 13558             0              99  United-States   >50K           1
# 9831              0              99  United-States  <=50K           0
# 13580             0              99  United-States  <=50K           0
# ...             ...             ...            ...    ...         ...
# 23481             0              53  United-States  <=50K           0
# 28858             0              53  United-States  <=50K           0
# 15889             0              53  United-States  <=50K           0
# 15908             0              53  United-States  <=50K           0
# 5345              0              53  United-States  <=50K           0
#
# [3492 rows x 15 columns]

# %%
df[(df["hours-per-week"] == 99)].sample(10)
# Out:
#        age         workclass  fnlwgt     education         marital-status  \
# 26638   55  Self-emp-not-inc  185195     Bachelors     Married-civ-spouse
# 22216   45           Private   54260  Some-college               Divorced
# 15180   25           Private  356017          11th          Never-married
# 30992   40      Self-emp-inc  104235       Masters          Never-married
# 6898    53  Self-emp-not-inc  151159          10th  Married-spouse-absent
# 10143   35           Unknown  164866          10th               Divorced
# 15016   62           Private  272209       HS-grad               Divorced
# 25806   49           Unknown   31478       7th-8th     Married-civ-spouse
# 935     37           Private  176900       HS-grad     Married-civ-spouse
# 26250   36  Self-emp-not-inc  257250     Assoc-voc     Married-civ-spouse
#
#              occupation relationship   race     sex  capital-gain  \
# 26638   Exec-managerial      Husband  White    Male             0
# 22216      Craft-repair    Unmarried  White    Male             0
# 15180     Other-service    Unmarried  White    Male             0
# 30992     Other-service         None  White    Male             0
# 6898   Transport-moving    Unmarried  White    Male             0
# 10143           Unknown    Unmarried  White    Male             0
# 15016   Priv-house-serv    Unmarried  Black  Female             0
# 25806           Unknown      Husband  White    Male             0
# 935        Craft-repair      Husband  White    Male             0
# 26250   Farming-fishing      Husband  White    Male             0
#
#        capital-loss  hours-per-week native-country salary  salary_num
# 26638             0              99  United-States  <=50K           0
# 22216             0              99  United-States  <=50K           0
# 15180             0              99  United-States  <=50K           0
# 30992             0              99  United-States  <=50K           0
# 6898              0              99  United-States  <=50K           0
# 10143             0              99  United-States  <=50K           0
# 15016             0              99  United-States  <=50K           0
# 25806             0              99  United-States  <=50K           0
# 935               0              99  United-States   >50K           1
# 26250             0              99  United-States  <=50K           0

# %%
df[(df["hours-per-week"] == 99)].age.value_counts().sort_index(ascending=False)
# Out:
# 90    1
# 73    1
# 72    1
# 67    1
# 66    2
# 65    1
# 64    1
# 62    1
# 61    2
# 59    1
# 58    2
# 56    1
# 55    3
# 53    3
# 51    4
# 50    2
# 49    2
# 45    3
# 44    4
# 43    6
# 42    1
# 40    2
# 39    5
# 38    5
# 37    4
# 36    1
# 35    3
# 34    1
# 33    1
# 32    2
# 31    4
# 30    3
# 29    1
# 28    2
# 27    3
# 26    1
# 25    2
# 24    1
# 19    1
# Name: age, dtype: int64

# %% [markdown]
# ### Boxplot and Histplot for all numeric features

# %%
index = 0
plt.figure(figsize=(20,10))
for feature in df.select_dtypes('number').columns:
    index += 1
    plt.subplot(2,3,index)
    sns.boxplot(x=feature, data=df, whis=1.5)

# %%
index = 0
plt.figure(figsize=(20,40))
for feature in df.select_dtypes('number').columns:
    index += 1
    plt.subplot(6,2, index)
    sns.boxplot(x=feature, data=df, whis=1.5)
    index += 1
    plt.subplot(6,2,index)
    sns.histplot(x=feature, data=df)

# %% [markdown]
# # After looking at the outliers you can drop the rows which actually does not make any sense.
# **Hint: You can check age and hours per week columns.**
#
# find outlier values which extends the upper limit in both age and hours-per-week columns

# %%
df[(df['age']>78) & (df['hours-per-week']>52.5)]
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 3777    80       Private   87518  Some-college       Never-married
# 5370    90     Local-gov  227796       Masters  Married-civ-spouse
# 7481    83       Private  195507       HS-grad             Widowed
# 7720    84       Private  241065       Masters       Never-married
# 8806    90       Private   87372   Prof-school  Married-civ-spouse
# 11996   90       Private   40388     Bachelors       Never-married
# 12830   81       Private  201398       Masters             Widowed
# 15356   90       Private   90523       HS-grad             Widowed
# 24395   83  Self-emp-inc  153183     Bachelors  Married-civ-spouse
#
#              occupation relationship   race   sex  capital-gain  capital-loss  \
# 3777     Prof-specialty    Unmarried  White  Male             0          1816
# 5370    Exec-managerial      Husband  White  Male         20051             0
# 7481    Protective-serv    Unmarried  White  Male             0             0
# 7720     Prof-specialty    Unmarried  White  Male             0             0
# 8806     Prof-specialty      Husband  White  Male         20051             0
# 11996   Exec-managerial    Unmarried  White  Male             0             0
# 12830    Prof-specialty    Unmarried  White  Male             0             0
# 15356  Transport-moving    Unmarried  White  Male             0             0
# 24395   Exec-managerial      Husband  White  Male             0          2392
#
#        hours-per-week native-country salary  salary_num
# 3777               60  United-States  <=50K           0
# 5370               60  United-States   >50K           1
# 7481               55  United-States  <=50K           0
# 7720               66  United-States  <=50K           0
# 8806               72  United-States   >50K           1
# 11996              55  United-States  <=50K           0
# 12830              60        Unknown  <=50K           0
# 15356              99  United-States  <=50K           0
# 24395              55  United-States   >50K           1

# %%
drop_index=df[(df['age']>78) & (df['hours-per-week']>52.5)].index
drop_index
# Out:
# Int64Index([3777, 5370, 7481, 7720, 8806, 11996, 12830, 15356, 24395], dtype='int64')

# %%
df.drop(index=drop_index, inplace=True)

# %%
# check outlier values which extends the upper limit in both age and hours-per-week columns
df[(df['age']>78) & (df['hours-per-week']>52.5)]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary, salary_num]
# Index: []

# %% [markdown]
# ---
# # How many of each race are represented in this dataset?
# ---

# %%
df.race.value_counts()
# Out:
# White                 27807
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
df.race.value_counts().plot.barh();  #.plot  ,  .plt.bar python gomulu fonksiyonu

# %%
sns.countplot(df.race)
# Out:
# <AxesSubplot:xlabel='race', ylabel='count'>

# %% [markdown]
# ---
# # What is the average age of men/women?
# ---

# %%
average_age_men = df.loc[df['sex']=='Male','age'].mean()
average_age_men
# Out:
# 39.41444378127726

# %%
average_age_men1 = df[df.sex=='Male']['age'].mean()
average_age_men1
# Out:
# 39.41444378127726

# %%
round(average_age_men,1)
# Out:
# 39.4

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Male", "age"].value_counts().plot.bar();

# %%
average_age_women = df.loc[df.sex=='Female','age'].mean()
average_age_women
# Out:
# 36.85823043357163

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Female", "age"].value_counts().plot.bar();

# %% [markdown]
# ---
# # What is the percentage of people who have a Bachelor's degree?
# ---

# %%
df.groupby('education').education.count()
# Out:
# education
# 10th              933
# 11th             1175
# 12th              433
# 1st-4th           168
# 5th-6th           333
# 7th-8th           646
# 9th               514
# Assoc-acdm       1067
# Assoc-voc        1382
# Bachelors        5353
# Doctorate         413
# HS-grad         10499
# Masters          1720
# Preschool          51
# Prof-school       575
# Some-college     7290
# Name: education, dtype: int64

# %%
df.education.value_counts()
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
df.education.value_counts().loc['Bachelors']
# Out:
# 5353

# %%
len(df)
# Out:
# 32552

# %%
bachelors = df.education.value_counts().loc['Bachelors']
total = len(df)

# %%
percentage_bachelors = bachelors / total * 100
percentage_bachelors
# Out:
# 16.44445809781273

# %%
df["education"].value_counts(normalize=True)
# df["education"].value_counts(normalize=True)[2] # indexle Bachelor'u cekebiliriz
# Out:
# HS-grad        0.323
# Some-college   0.224
# Bachelors      0.164
# Masters        0.053
# Assoc-voc      0.042
# 11th           0.036
# Assoc-acdm     0.033
# 10th           0.029
# 7th-8th        0.020
# Prof-school    0.018
# 9th            0.016
# 12th           0.013
# Doctorate      0.013
# 5th-6th        0.010
# 1st-4th        0.005
# Preschool      0.002
# Name: education, dtype: float64

# %%
percentage_bachelors = df["education"].value_counts(normalize=True).loc["Bachelors"]*100
round(percentage_bachelors,1)
# Out:
# 16.4

# %%
print(f"The percentage of people who have a Bachelor's degree : %{round(percentage_bachelors,1)}")
# Out:
# The percentage of people who have a Bachelor's degree : %16.4

# %% [markdown]
# ---
# # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
# ---

# %%
df.salary.value_counts()
# Out:
# <=50K    24714
# >50K      7838
# Name: salary, dtype: int64

# %%
df.education.value_counts()
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
df.education.isin(["Bachelors", "Masters", "Doctorate"])
#(df.education=='Bachelors') | (df.education=='Masters') | (df.education=='Doctorate')
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32552, dtype: bool

# %%
df.salary=='>50K'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557     True
# 32558    False
# 32559    False
# 32560     True
# Name: salary, Length: 32552, dtype: bool

# %%
df[(df.education.isin(["Bachelors", "Masters", "Doctorate"]))&(df.salary=='>50K')]
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 8       31           Private   45781    Masters       Never-married
# 9       42           Private  159449  Bachelors  Married-civ-spouse
# 11      30         State-gov  141297  Bachelors  Married-civ-spouse
# 19      43  Self-emp-not-inc  292175    Masters            Divorced
# 20      40           Private  193524  Doctorate  Married-civ-spouse
# ...    ...               ...     ...        ...                 ...
# 32533   54           Private  337992  Bachelors  Married-civ-spouse
# 32536   34           Private  160216  Bachelors       Never-married
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           Unknown  287372  Doctorate  Married-civ-spouse
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# 8       Prof-specialty    Unmarried               White  Female         14084
# 9      Exec-managerial      Husband               White    Male          5178
# 11      Prof-specialty      Husband  Asian-Pac-Islander    Male             0
# 19     Exec-managerial    Unmarried               White  Female             0
# 20      Prof-specialty      Husband               White    Male             0
# ...                ...          ...                 ...     ...           ...
# 32533  Exec-managerial      Husband  Asian-Pac-Islander    Male             0
# 32536  Exec-managerial    Unmarried               White  Female             0
# 32538   Prof-specialty    Unmarried               Black  Female         15020
# 32539          Unknown      Husband               White    Male             0
# 32554  Exec-managerial      Husband               White    Male             0
#
#        capital-loss  hours-per-week native-country salary  salary_num
# 8                 0              50  United-States   >50K           1
# 9                 0              40  United-States   >50K           1
# 11                0              40          India   >50K           1
# 19                0              45  United-States   >50K           1
# 20                0              60  United-States   >50K           1
# ...             ...             ...            ...    ...         ...
# 32533             0              50          Japan   >50K           1
# 32536             0              55  United-States   >50K           1
# 32538             0              45  United-States   >50K           1
# 32539             0              10  United-States   >50K           1
# 32554             0              40  United-States   >50K           1
#
# [3484 rows x 15 columns]

# %%
len(df[(df.education.isin(["Bachelors", "Masters", "Doctorate"]))&(df.salary=='>50K')])
# Out:
# 3484

# %%
df[(df.education.isin(["Bachelors", "Masters", "Doctorate"]))&(df.salary=='>50K')].shape[0]
# Out:
# 3484

# %%
high_edu_high_sal = len(df[(df.education.isin(["Bachelors", "Masters", "Doctorate"]))&(df.salary=='>50K')])
total = df.shape[0]

# %%
perc_high_edu = high_edu_high_sal/total
perc_high_edu
# Out:
# 0.10702875399361023

# %%
print(f"Percentage of people with advanced education make more than 50K : {round(perc_high_edu * 100, 2)}")
# Out:
# Percentage of people with advanced education make more than 50K : 10.7

# %% [markdown]
# ---
# # What percentage of people without advanced education make more than 50K?
# ---

# %%
df[(~df.education.isin(["Bachelors", "Masters", "Doctorate"]))&(df.salary=='>50K')]
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 7       52  Self-emp-not-inc  209642       HS-grad  Married-civ-spouse
# 10      37           Private  280464  Some-college  Married-civ-spouse
# 14      40           Private  121772     Assoc-voc  Married-civ-spouse
# 27      54           Unknown  180211  Some-college  Married-civ-spouse
# 38      31           Private   84154  Some-college  Married-civ-spouse
# ...    ...               ...     ...           ...                 ...
# 32518   57         Local-gov  110417       HS-grad  Married-civ-spouse
# 32519   46           Private  364548  Some-college  Married-civ-spouse
# 32545   39         Local-gov  111499    Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374       HS-grad  Married-civ-spouse
# 32560   52      Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship                race     sex  \
# 7        Exec-managerial      Husband               White    Male
# 10       Exec-managerial      Husband               Black    Male
# 14          Craft-repair      Husband  Asian-Pac-Islander    Male
# 27               Unknown      Husband  Asian-Pac-Islander    Male
# 38                 Sales      Husband               White    Male
# ...                  ...          ...                 ...     ...
# 32518       Craft-repair      Husband               White    Male
# 32519    Exec-managerial      Husband               White    Male
# 32545       Adm-clerical         Wife               White  Female
# 32557  Machine-op-inspct      Husband               White    Male
# 32560    Exec-managerial         Wife               White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary  \
# 7                 0             0              45  United-States   >50K
# 10                0             0              80  United-States   >50K
# 14                0             0              40        Unknown   >50K
# 27                0             0              60          South   >50K
# 38                0             0              38        Unknown   >50K
# ...             ...           ...             ...            ...    ...
# 32518         99999             0              40  United-States   >50K
# 32519             0             0              48  United-States   >50K
# 32545             0             0              20  United-States   >50K
# 32557             0             0              40  United-States   >50K
# 32560         15024             0              40  United-States   >50K
#
#        salary_num
# 7               1
# 10              1
# 14              1
# 27              1
# 38              1
# ...           ...
# 32518           1
# 32519           1
# 32545           1
# 32557           1
# 32560           1
#
# [4354 rows x 15 columns]

# %%
low_edu_high_sal = len(df[(~df.education.isin(["Bachelors", "Masters", "Doctorate"]))&(df.salary=='>50K')])
total = df.shape[0]

# %%
perc_low_edu = low_edu_high_sal/total
perc_low_edu
# Out:
# 0.13375522241336937

# %%
print(f"Percentage of people without advanced education make more than 50K : {round(perc_low_edu * 100 ,2)}")
# Out:
# Percentage of people without advanced education make more than 50K : 13.38

# %%
if perc_high_edu > perc_low_edu :
    print("More education more money!")
else:
    print("Education has no clear effet on salary. You should investigate some other features also.")
# Out:
# Education has no clear effet on salary. You should investigate some other features also.

# %% [markdown]
# ---
# # What percentage of the people who work the minimum number of hours per week have a salary of >50K?
# ---

# %%
df['hours-per-week'].value_counts()
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1472
# 35     1297
# 20     1224
# 30     1149
# 55      691
# 25      674
# 48      517
# 38      476
# 15      404
# 70      291
# 10      278
# 32      266
# 24      252
# 65      244
# 36      220
# 42      219
# 44      212
# 16      205
# 12      173
# 43      151
# 37      149
# 8       145
# 52      138
# 80      133
# 56       97
# 28       86
# 99       84
# 46       82
# 18       75
# 72       70
# 75       66
# 6        64
# 5        60
# 4        54
# 47       49
# 84       45
# 22       44
# 54       41
# 3        39
# 33       39
# 39       38
# 41       36
# 14       34
# 2        32
# 27       30
# 26       30
# 49       29
# 90       29
# 17       29
# 34       28
# 58       28
# 7        26
# 53       25
# 21       24
# 13       23
# 23       21
# 1        20
# 62       18
# 9        18
# 57       17
# 66       16
# 64       14
# 19       14
# 51       13
# 85       13
# 68       12
# 11       11
# 98       11
# 63       10
# 78        8
# 29        7
# 77        6
# 31        5
# 96        5
# 59        5
# 67        4
# 91        3
# 81        3
# 76        3
# 95        2
# 61        2
# 89        2
# 73        2
# 88        2
# 86        2
# 97        2
# 92        1
# 74        1
# 94        1
# 82        1
# 87        1
# Name: hours-per-week, dtype: int64

# %%
lazy_riches = (df['hours-per-week']==df['hours-per-week'].min()) & (df.salary=='>50K')
lazy_riches
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32552, dtype: bool

# %%
df[lazy_riches]
# Out:
#        age  workclass  fnlwgt  education      marital-status      occupation  \
# 189     58  State-gov  109567  Doctorate  Married-civ-spouse  Prof-specialty
# 20072   65    Unknown   76043    HS-grad  Married-civ-spouse         Unknown
#
#       relationship   race   sex  capital-gain  capital-loss  hours-per-week  \
# 189        Husband  White  Male             0             0               1
# 20072      Husband  White  Male             0             0               1
#
#       native-country salary  salary_num
# 189    United-States   >50K           1
# 20072  United-States   >50K           1

# %%
num_lazy_riches = df[lazy_riches].shape[0]
num_lazy_riches
# Out:
# 2

# %%
num_min_workers = len(df[df['hours-per-week']==df['hours-per-week'].min()])
num_min_workers
# Out:
# 20

# %%
print (f"Percentage of the people who work the minimum number of hours per week have a salary of >50K : % {round(num_lazy_riches/num_min_workers*100)}")
# Out:
# Percentage of the people who work the minimum number of hours per week have a salary of >50K : % 10

# %% [markdown]
#  ---
#  # What country has the highest percentage of people that earn >50K?
#  ---

# %%
country_salary_df = df.groupby('native-country')[['salary']].count()
country_salary_df
# Out:
#                             salary
# native-country
# Cambodia                        19
# Canada                         121
# China                           75
# Columbia                        59
# Cuba                            95
# Dominican-Republic              70
# Ecuador                         28
# El-Salvador                    106
# England                         90
# France                          29
# Germany                        137
# Greece                          29
# Guatemala                       64
# Haiti                           44
# Holand-Netherlands               1
# Honduras                        13
# Hong                            20
# Hungary                         13
# India                          100
# Iran                            43
# Ireland                         24
# Italy                           73
# Jamaica                         81
# Japan                           62
# Laos                            18
# Mexico                         643
# Nicaragua                       34
# Outlying-US(Guam-USVI-etc)      14
# Peru                            31
# Philippines                    198
# Poland                          60
# Portugal                        37
# Puerto-Rico                    114
# Scotland                        12
# South                           80
# Taiwan                          51
# Thailand                        18
# Trinadad&Tobago                 19
# United-States                29162
# Unknown                        582
# Vietnam                         67
# Yugoslavia                      16

# %%
country_salary_df_riches = df[df.salary=='>50K'].groupby('native-country')[['salary']].count()
country_salary_df_riches
# Out:
#                     salary
# native-country
# Cambodia                 7
# Canada                  39
# China                   20
# Columbia                 2
# Cuba                    25
# Dominican-Republic       2
# Ecuador                  4
# El-Salvador              9
# England                 30
# France                  12
# Germany                 44
# Greece                   8
# Guatemala                3
# Haiti                    4
# Honduras                 1
# Hong                     6
# Hungary                  3
# India                   40
# Iran                    18
# Ireland                  5
# Italy                   25
# Jamaica                 10
# Japan                   24
# Laos                     2
# Mexico                  33
# Nicaragua                2
# Peru                     2
# Philippines             61
# Poland                  12
# Portugal                 4
# Puerto-Rico             12
# Scotland                 3
# South                   16
# Taiwan                  20
# Thailand                 3
# Trinadad&Tobago          2
# United-States         7168
# Unknown                146
# Vietnam                  5
# Yugoslavia               6

# %%
rich_per_country = (country_salary_df_riches/country_salary_df).sort_values('salary',ascending=False)
rich_per_country
# Out:
#                             salary
# native-country
# Iran                         0.419
# France                       0.414
# India                        0.400
# Taiwan                       0.392
# Japan                        0.387
# Yugoslavia                   0.375
# Cambodia                     0.368
# Italy                        0.342
# England                      0.333
# Canada                       0.322
# Germany                      0.321
# Philippines                  0.308
# Hong                         0.300
# Greece                       0.276
# China                        0.267
# Cuba                         0.263
# Unknown                      0.251
# Scotland                     0.250
# United-States                0.246
# Hungary                      0.231
# Ireland                      0.208
# South                        0.200
# Poland                       0.200
# Thailand                     0.167
# Ecuador                      0.143
# Jamaica                      0.123
# Laos                         0.111
# Portugal                     0.108
# Puerto-Rico                  0.105
# Trinadad&Tobago              0.105
# Haiti                        0.091
# El-Salvador                  0.085
# Honduras                     0.077
# Vietnam                      0.075
# Peru                         0.065
# Nicaragua                    0.059
# Mexico                       0.051
# Guatemala                    0.047
# Columbia                     0.034
# Dominican-Republic           0.029
# Holand-Netherlands             NaN
# Outlying-US(Guam-USVI-etc)     NaN

# %%
rich_per_country[rich_per_country.salary==rich_per_country.salary.max()]
# Out:
#                 salary
# native-country
# Iran             0.419

# %%
rich_per_country.loc[[rich_per_country.salary.idxmax()]]
# Out:
#                 salary
# native-country
# Iran             0.419

# %%
rich_per_country.iloc[[0]]
# Out:
#                 salary
# native-country
# Iran             0.419

# %%
rich_per_country.plot.bar();

# %%
plt.figure(figsize=(12,6))
df.loc[((df["native-country"] == "Iran")), "salary"].value_counts().plot.bar();

# %%
plt.figure(figsize=(14,7))
df.loc[df["salary"] == ">50K", "native-country"].value_counts().plot(kind="bar");

# %% [markdown]
# ---
# # Identify the most popular occupation for those who earn >50K in India.
# ---

# %%
top_IN_occupation = (df['native-country']=='India') & (df.salary=='>50K')

top_IN_occupation
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32552, dtype: bool

# %%
df[top_IN_occupation]
# Out:
#        age         workclass  fnlwgt    education         marital-status  \
# 11      30         State-gov  141297    Bachelors     Married-civ-spouse
# 968     48           Private  164966    Bachelors     Married-civ-spouse
# 1327    52           Private  168381      HS-grad                Widowed
# 7258    42         State-gov  102343  Prof-school     Married-civ-spouse
# 7285    54         State-gov   93449      Masters     Married-civ-spouse
# 8124    36           Private  172104  Prof-school          Never-married
# 9939    43       Federal-gov  325706  Prof-school     Married-civ-spouse
# 10590   35           Private   98283  Prof-school          Never-married
# 10661   59           Private  122283  Prof-school     Married-civ-spouse
# 10736   30           Private  243190  Prof-school     Married-civ-spouse
# 11260   54           Private  225599      Masters     Married-civ-spouse
# 11384   34           Private   98283  Prof-school          Never-married
# 13422   53           Private  366957    Bachelors     Married-civ-spouse
# 13551   40           Private  220977    Doctorate     Married-civ-spouse
# 13862   45           Private  209912    Bachelors     Married-civ-spouse
# 16017   41           Private  207578   Assoc-acdm     Married-civ-spouse
# 16778   43           Private  242968      Masters     Married-civ-spouse
# 16923   41           Private  143003    Assoc-voc     Married-civ-spouse
# 17259   57      Self-emp-inc  123053  Prof-school     Married-civ-spouse
# 17834   29  Self-emp-not-inc  341672      HS-grad  Married-spouse-absent
# 20417   42      Self-emp-inc   23510      Masters               Divorced
# 20465   39           Private  198654  Prof-school     Married-civ-spouse
# 21128   30           Private  122889      Masters     Married-civ-spouse
# 23474   55         State-gov  120781    Doctorate     Married-civ-spouse
# 24154   46           Private  229737    Bachelors     Married-civ-spouse
# 25739   35      Self-emp-inc   79586      Masters     Married-civ-spouse
# 26305   27           Private  207352    Bachelors     Married-civ-spouse
# 26356   34           Private   99872      Masters     Married-civ-spouse
# 27670   61           Private   80896      Masters     Married-civ-spouse
# 28264   51  Self-emp-not-inc  120781  Prof-school     Married-civ-spouse
# 28433   42           Private  198341      Masters     Married-civ-spouse
# 28452   53           Private   70387      Masters     Married-civ-spouse
# 28557   34           Private  165737      Masters     Married-civ-spouse
# 28651   45  Self-emp-not-inc  216402  Prof-school     Married-civ-spouse
# 28798   30  Self-emp-not-inc  116666      Masters               Divorced
# 30111   41       Federal-gov  219155  Prof-school     Married-civ-spouse
# 30152   48           Private  119471    Doctorate     Married-civ-spouse
# 30833   25           Private  110978   Assoc-acdm     Married-civ-spouse
# 31327   38         State-gov  125499    Bachelors     Married-civ-spouse
# 31357   23           Private  143003      Masters     Married-civ-spouse
#
#              occupation relationship                race     sex  \
# 11       Prof-specialty      Husband  Asian-Pac-Islander    Male
# 968     Exec-managerial      Husband  Asian-Pac-Islander    Male
# 1327      Other-service    Unmarried  Asian-Pac-Islander  Female
# 7258     Prof-specialty      Husband  Asian-Pac-Islander    Male
# 7285     Prof-specialty      Husband  Asian-Pac-Islander    Male
# 8124     Prof-specialty    Unmarried               Other    Male
# 9939     Prof-specialty      Husband  Asian-Pac-Islander    Male
# 10590    Prof-specialty    Unmarried  Asian-Pac-Islander    Male
# 10661    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 10736    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 11260    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 11384      Tech-support    Unmarried  Asian-Pac-Islander    Male
# 13422   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 13551   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 13862   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 16017   Exec-managerial      Husband               Black    Male
# 16778   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 16923     Other-service      Husband  Asian-Pac-Islander    Male
# 17259    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 17834  Transport-moving    Unmarried  Asian-Pac-Islander    Male
# 20417   Exec-managerial    Unmarried  Asian-Pac-Islander    Male
# 20465    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 21128    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 23474    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 24154             Sales      Husband               White    Male
# 25739    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 26305      Tech-support      Husband  Asian-Pac-Islander    Male
# 26356   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 27670    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28264    Prof-specialty      Husband               Other    Male
# 28433    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28452    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28557    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28651    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28798    Prof-specialty    Unmarried  Asian-Pac-Islander    Male
# 30111    Prof-specialty      Husband               White    Male
# 30152    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 30833      Adm-clerical         Wife  Asian-Pac-Islander  Female
# 31327    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 31357    Prof-specialty      Husband  Asian-Pac-Islander    Male
#
#        capital-gain  capital-loss  hours-per-week native-country salary  \
# 11                0             0              40          India   >50K
# 968               0             0              40          India   >50K
# 1327              0             0              40          India   >50K
# 7258              0             0              72          India   >50K
# 7285              0             0              40          India   >50K
# 8124              0             0              40          India   >50K
# 9939              0             0              50          India   >50K
# 10590             0             0              40          India   >50K
# 10661         99999             0              40          India   >50K
# 10736             0             0              20          India   >50K
# 11260          7298             0              40          India   >50K
# 11384             0          1564              40          India   >50K
# 13422         99999             0              50          India   >50K
# 13551          3103             0              40          India   >50K
# 13862             0             0              40          India   >50K
# 16017             0             0              50          India   >50K
# 16778             0             0              40          India   >50K
# 16923          7298             0              60          India   >50K
# 17259         15024             0              50          India   >50K
# 17834             0          1564              50          India   >50K
# 20417             0          2201              60          India   >50K
# 20465             0          2415              67          India   >50K
# 21128             0             0              50          India   >50K
# 23474             0             0              40          India   >50K
# 24154             0             0              50          India   >50K
# 25739             0             0              40          India   >50K
# 26305             0             0              40          India   >50K
# 26356          3103             0              40          India   >50K
# 27670             0             0              45          India   >50K
# 28264         99999             0              70          India   >50K
# 28433             0          1902              55          India   >50K
# 28452          4386             0              40          India   >50K
# 28557             0             0              43          India   >50K
# 28651             0             0              50          India   >50K
# 28798             0             0              50          India   >50K
# 30111             0             0              50          India   >50K
# 30152             0             0              40          India   >50K
# 30833             0             0              37          India   >50K
# 31327          7688             0              60          India   >50K
# 31357             0          1887              50          India   >50K
#
#        salary_num
# 11              1
# 968             1
# 1327            1
# 7258            1
# 7285            1
# 8124            1
# 9939            1
# 10590           1
# 10661           1
# 10736           1
# 11260           1
# 11384           1
# 13422           1
# 13551           1
# 13862           1
# 16017           1
# 16778           1
# 16923           1
# 17259           1
# 17834           1
# 20417           1
# 20465           1
# 21128           1
# 23474           1
# 24154           1
# 25739           1
# 26305           1
# 26356           1
# 27670           1
# 28264           1
# 28433           1
# 28452           1
# 28557           1
# 28651           1
# 28798           1
# 30111           1
# 30152           1
# 30833           1
# 31327           1
# 31357           1

# %%
df[top_IN_occupation]['occupation'].value_counts()
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Adm-clerical         1
# Sales                1
# Transport-moving     1
# Name: occupation, dtype: int64

# %%
df[top_IN_occupation]['occupation'].value_counts().index[0]
# Out:
# 'Prof-specialty'

# %%
 #use mode here
a =  df[top_IN_occupation]["occupation"].mode()[0]
a
# Out:
# 'Prof-specialty'

# %%
print(f"{a} the most popular occupation for those who earn >50K in India.")
# Out:
# Prof-specialty the most popular occupation for those who earn >50K in India.

# %% [markdown]
# ----
# ---
